# %% [markdown]
# <a href="https://colab.research.google.com/github/LorenzoCazottiBraga/INTED_2025/blob/main/30-10-2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Peça um número e informe se ele é maior que 10. Crie um algoritmo em Python para fazer essa verificação.
a = float(input('digite um número: '))
if a > 10:
  print('esse numero é maior que 10')
else:
  print('esse número é menor ou igual a 10')
# Out:
# digite um número: 15
# esse numero é maior que 10

# %%
# Peça um número inteiro e informe se ele é par. Crie um algoritmo em Python que verifique se o número é divisível por 2.
a = int(input('digite um número: '))
if a % 2 == 0:
  print('esse número é par')
else:
  print('esse número é impar')
# Out:
# digite um número: 2222222222222222222222222222222222222222222222222222222222222222222222221
# esse número é impar

# %%
# Peça um nome e informe se ele contém a letra "a". Crie um algoritmo em Python que faça essa verificação.
b = str(input('digite uma palavra: '))
if "a" in b.lower():
  print('essa palavra tem a')
else:
  print('essa palavra não tem a')
# Out:
# digite uma palavra: corvo
# essa palavra não tem a

# %%
# Peça um número e informe se ele é múltiplo de 5. Crie um algoritmo em Python que verifique se o número é divisível por 5.
a = int(input('digite um número: '))
if a % 5 == 0:
  print('esse número é multiplo de 5')
else:
  print('esse número não é multiplo de 5')
# Out:
# digite um número: 75
# esse número é multiplo de 5

# %%
# Peça a temperatura atual e informe se está quente (acima de 30°C) ou frio (30°C ou menos). Crie um algoritmo em Python para essa verificação.
a = int(input('digite uma temperatura: '))
if a > 30:
  print('acima de 30°C. Está quente')
else:
  print('abaixo de 30°C. Está frio')
# Out:
# digite uma temperatura: 25
# abaixo de 30°C. Está frio

# %%
# Peça ao usuário para digitar "S" para continuar ou "N" para sair e informe a ação correspondente. Crie um algoritmo em Python que faça essa validação e exiba a mensagem correta.
b = str(input('digite "S" para continuar, caso contrário, digite "N": '))
if 'S' in b:
    print('você escolheu continuar')
elif 'N' in b:
    print('você escolheu não continuar')
else:
    print('ERRO, digite corretamente para o alistamento prosseguir')
# Out:
# digite "S" para continuar, caso contrário, digite "N": l
# ERRO, digite corretamente para o alistamento prosseguir

# %%
# Peça um número e informe se ele é negativo, zero ou positivo. Crie um algoritmo em Python para classificar o número.
a = float(input('digite um número: '))
if a > 0:
  print('número positivo')
elif a == 0:
  print('número igual a 0')
else:
  print('número negativo')
# Out:
# digite um número: 0
# número igual a 0

# %%
# Peça um número de 1 a 7 e informe o dia da semana correspondente. Crie um algoritmo em Python que associe o número ao dia correto.
a = int(input('digite um número inteiro de 1 a 7, e o programa responderá com o dia da semana correspondente: '))
if a == 1:
  print('Domingo')
elif a == 2:
  print('Segunda-Feira')
elif a == 3:
  print('Terça-Feira')
elif a == 4:
  print('Quarta-Feira')
elif a == 5:
  print('Quinta-Feira')
elif a == 6:
  print('Sexta-Feira')
elif a == 7:
  print('Sábado')
else:
  print('ERRO! digite um número de 1 a 7')
# Out:
# digite um número inteiro de 1 a 7, e o programa responderá com o dia da semana correspondente: 2
# Segunda-Feira

# %%
# Peça um ano e informe se ele é bissexto. Crie um algoritmo em Python que verifique se o ano é divisível por 4 e não por 100, exceto se também for divisível por 400.
a = int(input('digite um ano: '))
if (a % 4 == 0 and not(a % 100 == 0)) or (a % 400 == 0):
  print('É Bissexto')
else:
  print('Não é Bissexto')
# Out:
# digite um ano: 2013
# Não é Bissexto

# %%
# Peça a quantidade de horas trabalhadas e o valor por hora. Se trabalhou até 40 horas, calcule o salário normalmente (horas × valor por hora). Se trabalhou mais de 40 horas, as horas extras devem ter um adicional de 50% (horas extras × valor por hora × 1.5). Crie um algoritmo em Python que realize esse cálculo corretamente.
a = int(input('digite a quantidade de horas trabalhadas: '))
b = int(input('digite o valor por hora trabalhada: '))
extra = a * b + ((a-40) * b * 1.5)
salario = a * b
if a > 40:
  print('Seu salário é ', extra)
else:
  print('Seu salário é ', salario)
# Out:
# digite a quantidade de horas trabalhadas: 40
# digite o valor por hora trabalhada: 10
# Seu salário é  400
